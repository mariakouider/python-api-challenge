# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %%
api_key = "a58c010a24613dd40f4dfbd21fbc3e90"
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={api_key}&q={city}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | afaahiti
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | uturoa
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | papatowai
# Processing Record 9 of Set 1 | santa terezinha
# Processing Record 10 of Set 1 | remire-montjoly
# Processing Record 11 of Set 1 | cudahy
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | adamstown
# Processing Record 15 of Set 1 | porto novo
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 1 | tazovsky
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | sao bernardo
# Processing Record 21 of Set 1 | mizdah
# Processing Record 22 of Set 1 | tiksi
# Processing Record 23 of Set 1 | klyuchi
# Processing Record 24 of Set 1 | margaret river
# Processing Record 25 of Set 1 | edinburgh of the seven seas
# Processing Record 26 of Set 1 | bol'sherech'ye
# Processing Record 27 of Set 1 | olonkinbyen
# Processing Record 28 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 29 of Set 1 | tazacorte
# Processing Record 30 of Set 1 | inhambane
# Processing Record 31 of Set 1 | whitehorse
# Processing Record 32 of Set 1 | bairnsdale
# Processing Record 33 of Set 1 | waitangi
# Processing Record 34 of Set 1 | bilibino
# Processing Record 35 of Set 1 | karratha
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | belur
# Processing Record 38 of Set 1 | aykhal
# Processing Record 39 of Set 1 | bardai
# Processing Record 40 of Set 1 | kenai
# Processing Record 41 of Set 1 | as sanad
# Processing Record 42 of Set 1 | tura
# Processing Record 43 of Set 1 | reyes
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | las tablas
# Processing Record 46 of Set 1 | bayganin
# Processing Record 47 of Set 1 | griffith
# Processing Record 48 of Set 1 | san ignacio de velasco
# Processing Record 49 of Set 1 | puerto natales
# Processing Record 50 of Set 1 | luanda
# Processing Record 0 of Set 2 | new norfolk
# Processing Record 1 of Set 2 | val-d'or
# Processing Record 2 of Set 2 | usogorsk
# Processing Record 3 of Set 2 | vadso
# Processing Record 4 of Set 2 | iskateley
# Processing Record 5 of Set 2 | vorkuta
# Processing Record 6 of Set 2 | kapuskasing
# Processing Record 7 of Set 2 | constantia
# Processing Record 8 of Set 2 | saguenay
# Processing Record 9 of Set 2 | galliano
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | mabini
# Processing Record 12 of Set 2 | sao fidelis
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | hayma'
# City not found. Skipping...
# Processing Record 16 of Set 2 | talnakh
# Processing Record 17 of Set 2 | st. john's
# Processing Record 18 of Set 2 | guerrero negro
# Processing Record 19 of Set 2 | kassala
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | san marcos
# Processing Record 22 of Set 2 | roma
# Processing Record 23 of Set 2 | nova sintra
# Processing Record 24 of Set 2 | fale old settlement
# Processing Record 25 of Set 2 | polyarnyy
# Processing Record 26 of Set 2 | invercargill
# Processing Record 27 of Set 2 | guardo
# Processing Record 28 of Set 2 | east london
# Processing Record 29 of Set 2 | gamba
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | flying fish cove
# Processing Record 32 of Set 2 | alice springs
# Processing Record 33 of Set 2 | nar'yan-mar
# Processing Record 34 of Set 2 | watsa
# Processing Record 35 of Set 2 | dadeldhura
# Processing Record 36 of Set 2 | whitecourt
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | negombo
# Processing Record 39 of Set 2 | aketi
# Processing Record 40 of Set 2 | yerofey pavlovich
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 44 of Set 2 | phan thiet
# Processing Record 45 of Set 2 | utrik
# Processing Record 46 of Set 2 | queenstown
# Processing Record 47 of Set 2 | blackmans bay
# Processing Record 48 of Set 2 | enewetak
# Processing Record 49 of Set 2 | tangalle
# Processing Record 0 of Set 3 | puerto colombia
# Processing Record 1 of Set 3 | codrington
# Processing Record 2 of Set 3 | kelso
# Processing Record 3 of Set 3 | vila velha
# Processing Record 4 of Set 3 | polna
# Processing Record 5 of Set 3 | kodinsk
# Processing Record 6 of Set 3 | santa rosa
# Processing Record 7 of Set 3 | cabedelo
# Processing Record 8 of Set 3 | severo-yeniseyskiy
# Processing Record 9 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 3 | mejit
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | naju
# Processing Record 13 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 14 of Set 3 | crane
# Processing Record 15 of Set 3 | cockburn town
# Processing Record 16 of Set 3 | sangkhla buri
# Processing Record 17 of Set 3 | cidreira
# Processing Record 18 of Set 3 | la passe
# Processing Record 19 of Set 3 | baruun-urt
# Processing Record 20 of Set 3 | ust-nera
# Processing Record 21 of Set 3 | nuuk
# Processing Record 22 of Set 3 | anadyr
# Processing Record 23 of Set 3 | pont rouge
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | okhotsk
# Processing Record 26 of Set 3 | taksimo
# Processing Record 27 of Set 3 | jiayuguan
# Processing Record 28 of Set 3 | puerto baquerizo moreno
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | damavand
# Processing Record 31 of Set 3 | al markaz
# Processing Record 32 of Set 3 | dunedin
# Processing Record 33 of Set 3 | gunnison
# Processing Record 34 of Set 3 | yuzhno-kurilsk
# Processing Record 35 of Set 3 | ventspils
# Processing Record 36 of Set 3 | seogwipo
# City not found. Skipping...
# Processing Record 37 of Set 3 | sisimiut
# Processing Record 38 of Set 3 | san andres
# Processing Record 39 of Set 3 | juneau
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | kavaratti
# Processing Record 42 of Set 3 | haiku-pauwela
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | bhimunipatnam
# Processing Record 45 of Set 3 | mawu
# Processing Record 46 of Set 3 | touros
# Processing Record 47 of Set 3 | daniel flores
# Processing Record 48 of Set 3 | stanley
# Processing Record 49 of Set 3 | filey
# Processing Record 0 of Set 4 | qarauyl
# Processing Record 1 of Set 4 | yamaguchi
# Processing Record 2 of Set 4 | mandan
# Processing Record 3 of Set 4 | taraz
# Processing Record 4 of Set 4 | krasnogvardeyskoye
# Processing Record 5 of Set 4 | peshkopi
# Processing Record 6 of Set 4 | carnarvon
# Processing Record 7 of Set 4 | el granada
# Processing Record 8 of Set 4 | katsuura
# Processing Record 9 of Set 4 | ulsteinvik
# Processing Record 10 of Set 4 | port lincoln
# Processing Record 11 of Set 4 | bonthe
# Processing Record 12 of Set 4 | qaqortoq
# Processing Record 13 of Set 4 | okha
# Processing Record 14 of Set 4 | college
# Processing Record 15 of Set 4 | callao
# Processing Record 16 of Set 4 | banikoara
# Processing Record 17 of Set 4 | reggane
# Processing Record 18 of Set 4 | umluj
# Processing Record 19 of Set 4 | wailua homesteads
# Processing Record 20 of Set 4 | selfoss
# Processing Record 21 of Set 4 | pathein
# Processing Record 22 of Set 4 | avon
# Processing Record 23 of Set 4 | malanje
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | esquina
# Processing Record 28 of Set 4 | san antonio de pale
# Processing Record 29 of Set 4 | susuman
# Processing Record 30 of Set 4 | weno
# Processing Record 31 of Set 4 | hamilton
# Processing Record 32 of Set 4 | sennoy
# Processing Record 33 of Set 4 | atafu village
# Processing Record 34 of Set 4 | melfort
# Processing Record 35 of Set 4 | luang prabang
# Processing Record 36 of Set 4 | saipan
# Processing Record 37 of Set 4 | hadibu
# Processing Record 38 of Set 4 | hardys memories of africa
# City not found. Skipping...
# Processing Record 39 of Set 4 | hawaiian paradise park
# Processing Record 40 of Set 4 | udachny
# Processing Record 41 of Set 4 | kolonia
# Processing Record 42 of Set 4 | kununurra
# Processing Record 43 of Set 4 | robore
# Processing Record 44 of Set 4 | bayanaul
# Processing Record 45 of Set 4 | severnoye
# Processing Record 46 of Set 4 | dudinka
# Processing Record 47 of Set 4 | port alberni
# Processing Record 48 of Set 4 | mount pearl
# Processing Record 49 of Set 4 | kayunga
# Processing Record 0 of Set 5 | dampit
# Processing Record 1 of Set 5 | flin flon
# Processing Record 2 of Set 5 | kuching
# Processing Record 3 of Set 5 | nyurba
# Processing Record 4 of Set 5 | cururupu
# Processing Record 5 of Set 5 | minab
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | razdol'noye
# Processing Record 8 of Set 5 | fort bragg
# Processing Record 9 of Set 5 | nafada
# Processing Record 10 of Set 5 | harper
# Processing Record 11 of Set 5 | isafjordur
# Processing Record 12 of Set 5 | chornobayivka
# Processing Record 13 of Set 5 | aasiaat
# Processing Record 14 of Set 5 | colonia
# Processing Record 15 of Set 5 | khash
# Processing Record 16 of Set 5 | hermanus
# Processing Record 17 of Set 5 | andkhoy
# Processing Record 18 of Set 5 | mahibadhoo
# Processing Record 19 of Set 5 | torrington
# Processing Record 20 of Set 5 | tolanaro
# Processing Record 21 of Set 5 | shingu
# Processing Record 22 of Set 5 | conceicao da barra
# Processing Record 23 of Set 5 | lagos
# Processing Record 24 of Set 5 | horta
# Processing Record 25 of Set 5 | miles city
# Processing Record 26 of Set 5 | tchintabaraden
# Processing Record 27 of Set 5 | ati
# Processing Record 28 of Set 5 | sinop
# Processing Record 29 of Set 5 | luderitz
# Processing Record 30 of Set 5 | san fernando de apure
# Processing Record 31 of Set 5 | ketchikan
# Processing Record 32 of Set 5 | ijuw
# City not found. Skipping...
# Processing Record 33 of Set 5 | keflavik
# Processing Record 34 of Set 5 | kapsan-up
# Processing Record 35 of Set 5 | samana
# Processing Record 36 of Set 5 | dryden
# Processing Record 37 of Set 5 | cestos city
# Processing Record 38 of Set 5 | mangrol
# Processing Record 39 of Set 5 | manado
# Processing Record 40 of Set 5 | limon
# Processing Record 41 of Set 5 | port glaud
# City not found. Skipping...
# Processing Record 42 of Set 5 | hwange
# Processing Record 43 of Set 5 | barre
# Processing Record 44 of Set 5 | port mathurin
# Processing Record 45 of Set 5 | tamiahua
# Processing Record 46 of Set 5 | puerto leguizamo
# Processing Record 47 of Set 5 | kone
# Processing Record 48 of Set 5 | comandante fontana
# Processing Record 49 of Set 5 | port hueneme
# Processing Record 0 of Set 6 | cabo san lucas
# Processing Record 1 of Set 6 | sparti
# Processing Record 2 of Set 6 | eura
# Processing Record 3 of Set 6 | kingston
# Processing Record 4 of Set 6 | lihue
# Processing Record 5 of Set 6 | gizo
# Processing Record 6 of Set 6 | cape coast
# Processing Record 7 of Set 6 | argo
# Processing Record 8 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 9 of Set 6 | ventnor
# Processing Record 10 of Set 6 | srednebelaya
# Processing Record 11 of Set 6 | thompson
# Processing Record 12 of Set 6 | magadan
# Processing Record 13 of Set 6 | gnesta
# Processing Record 14 of Set 6 | tamanrasset
# Processing Record 15 of Set 6 | constitucion
# Processing Record 16 of Set 6 | danshui
# Processing Record 17 of Set 6 | bryne
# Processing Record 18 of Set 6 | santo antonio
# Processing Record 19 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 20 of Set 6 | tabou
# Processing Record 21 of Set 6 | merizo village
# Processing Record 22 of Set 6 | monrovia
# Processing Record 23 of Set 6 | malvan
# Processing Record 24 of Set 6 | kailua-kona
# Processing Record 25 of Set 6 | chegdomyn
# Processing Record 26 of Set 6 | verkhnevilyuysk
# Processing Record 27 of Set 6 | isla mujeres
# Processing Record 28 of Set 6 | tralee
# Processing Record 29 of Set 6 | altamira
# Processing Record 30 of Set 6 | sungai penuh
# Processing Record 31 of Set 6 | itamaraca
# Processing Record 32 of Set 6 | ugoofaaru
# Processing Record 33 of Set 6 | kiunga
# Processing Record 34 of Set 6 | ola
# Processing Record 35 of Set 6 | aiquile
# Processing Record 36 of Set 6 | tidjikja
# Processing Record 37 of Set 6 | suva
# Processing Record 38 of Set 6 | aioun
# Processing Record 39 of Set 6 | nouadhibou
# Processing Record 40 of Set 6 | buncrana
# Processing Record 41 of Set 6 | chilaw
# Processing Record 42 of Set 6 | ajaccio
# Processing Record 43 of Set 6 | napili-honokowai
# Processing Record 44 of Set 6 | vizinga
# Processing Record 45 of Set 6 | paracuru
# Processing Record 46 of Set 6 | hotan
# Processing Record 47 of Set 6 | berezovyy
# Processing Record 48 of Set 6 | laurentides
# Processing Record 49 of Set 6 | slave lake
# Processing Record 0 of Set 7 | tevriz
# Processing Record 1 of Set 7 | juan de ayolas
# Processing Record 2 of Set 7 | ardakan
# Processing Record 3 of Set 7 | ingeniero jacobacci
# Processing Record 4 of Set 7 | pinarhisar
# Processing Record 5 of Set 7 | namibe
# Processing Record 6 of Set 7 | mil'kovo
# Processing Record 7 of Set 7 | east grand forks
# Processing Record 8 of Set 7 | san julian
# Processing Record 9 of Set 7 | vorgashor
# Processing Record 10 of Set 7 | yagry
# City not found. Skipping...
# Processing Record 11 of Set 7 | zahedan
# Processing Record 12 of Set 7 | tsiombe
# Processing Record 13 of Set 7 | kayar
# Processing Record 14 of Set 7 | dawson creek
# Processing Record 15 of Set 7 | nizhneangarsk
# Processing Record 16 of Set 7 | champerico
# Processing Record 17 of Set 7 | huarmey
# Processing Record 18 of Set 7 | villa dolores
# Processing Record 19 of Set 7 | chelak
# Processing Record 20 of Set 7 | qingdao
# Processing Record 21 of Set 7 | acapulco de juarez
# Processing Record 22 of Set 7 | saint-philippe
# Processing Record 23 of Set 7 | ribeira brava
# Processing Record 24 of Set 7 | shantobe
# Processing Record 25 of Set 7 | balkh
# Processing Record 26 of Set 7 | parambu
# Processing Record 27 of Set 7 | natal
# Processing Record 28 of Set 7 | berdigestyakh
# Processing Record 29 of Set 7 | labytnangi
# Processing Record 30 of Set 7 | ta`u
# Processing Record 31 of Set 7 | tome acu
# Processing Record 32 of Set 7 | inongo
# Processing Record 33 of Set 7 | felege neway
# Processing Record 34 of Set 7 | idri
# Processing Record 35 of Set 7 | aswan
# Processing Record 36 of Set 7 | tocopilla
# Processing Record 37 of Set 7 | castillos
# Processing Record 38 of Set 7 | arteche
# Processing Record 39 of Set 7 | karasburg
# Processing Record 40 of Set 7 | turpan
# Processing Record 41 of Set 7 | ilebo
# Processing Record 42 of Set 7 | kuqa
# Processing Record 43 of Set 7 | antsohihy
# Processing Record 44 of Set 7 | nishinoomote
# Processing Record 45 of Set 7 | tomatlan
# Processing Record 46 of Set 7 | avrig
# Processing Record 47 of Set 7 | soio
# Processing Record 48 of Set 7 | newman
# Processing Record 49 of Set 7 | antofagasta
# Processing Record 0 of Set 8 | oroqen zizhiqi
# Processing Record 1 of Set 8 | barka'
# City not found. Skipping...
# Processing Record 2 of Set 8 | volodarskiy
# Processing Record 3 of Set 8 | manggar
# Processing Record 4 of Set 8 | grants pass
# Processing Record 5 of Set 8 | shenandoah
# Processing Record 6 of Set 8 | nikolayevsk-on-amure
# Processing Record 7 of Set 8 | ujae
# Processing Record 8 of Set 8 | bengkulu
# Processing Record 9 of Set 8 | zav'yalovo
# Processing Record 10 of Set 8 | badger
# Processing Record 11 of Set 8 | toliara
# Processing Record 12 of Set 8 | aldinga beach
# Processing Record 13 of Set 8 | sokoni
# Processing Record 14 of Set 8 | machico
# Processing Record 15 of Set 8 | padang
# Processing Record 16 of Set 8 | kashgar
# Processing Record 17 of Set 8 | kachkanar
# Processing Record 18 of Set 8 | puerto armuelles
# Processing Record 19 of Set 8 | fomboni
# Processing Record 20 of Set 8 | tobelo
# Processing Record 21 of Set 8 | tual
# Processing Record 22 of Set 8 | west island
# Processing Record 23 of Set 8 | betio village
# Processing Record 24 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 25 of Set 8 | sola
# Processing Record 26 of Set 8 | sahibganj
# Processing Record 27 of Set 8 | eastham
# Processing Record 28 of Set 8 | kerikeri
# Processing Record 29 of Set 8 | oranjemund
# Processing Record 30 of Set 8 | hammerfest
# Processing Record 31 of Set 8 | ingeniero guillermo n. juarez
# Processing Record 32 of Set 8 | sitka
# Processing Record 33 of Set 8 | acarau
# Processing Record 34 of Set 8 | kidal
# Processing Record 35 of Set 8 | lerwick
# Processing Record 36 of Set 8 | santa marta
# Processing Record 37 of Set 8 | xunchang
# Processing Record 38 of Set 8 | yorkton
# Processing Record 39 of Set 8 | ilheus
# Processing Record 40 of Set 8 | myitkyina
# Processing Record 41 of Set 8 | praia da vitoria
# Processing Record 42 of Set 8 | letlhakeng
# Processing Record 43 of Set 8 | brookings
# Processing Record 44 of Set 8 | hovd
# Processing Record 45 of Set 8 | rongelap
# Processing Record 46 of Set 8 | yeniseysk
# Processing Record 47 of Set 8 | lata
# Processing Record 48 of Set 8 | posto fiscal rolim de moura
# Processing Record 49 of Set 8 | chibougamau
# Processing Record 0 of Set 9 | bomdila
# Processing Record 1 of Set 9 | scarborough
# Processing Record 2 of Set 9 | florida
# Processing Record 3 of Set 9 | yarmouth
# Processing Record 4 of Set 9 | novodvinsk
# Processing Record 5 of Set 9 | wanning
# Processing Record 6 of Set 9 | irtyshsk
# Processing Record 7 of Set 9 | broome
# Processing Record 8 of Set 9 | alofi
# Processing Record 9 of Set 9 | akureyri
# Processing Record 10 of Set 9 | egilsstadir
# Processing Record 11 of Set 9 | tres palos
# Processing Record 12 of Set 9 | blenheim
# Processing Record 13 of Set 9 | toumodi
# Processing Record 14 of Set 9 | fort mcmurray
# Processing Record 15 of Set 9 | zhangye
# Processing Record 16 of Set 9 | alvaraes
# Processing Record 17 of Set 9 | pakala
# Processing Record 18 of Set 9 | portland
# Processing Record 19 of Set 9 | larkird
# Processing Record 20 of Set 9 | businga
# Processing Record 21 of Set 9 | bangassou
# Processing Record 22 of Set 9 | pakxan
# Processing Record 23 of Set 9 | ulladulla
# Processing Record 24 of Set 9 | sinnar
# Processing Record 25 of Set 9 | kawthoung
# City not found. Skipping...
# Processing Record 26 of Set 9 | dakhla
# Processing Record 27 of Set 9 | kralendijk
# Processing Record 28 of Set 9 | roslavl'
# Processing Record 29 of Set 9 | rio grande
# Processing Record 30 of Set 9 | kruisfontein
# Processing Record 31 of Set 9 | chamical
# Processing Record 32 of Set 9 | altai
# Processing Record 33 of Set 9 | kilindoni
# Processing Record 34 of Set 9 | fiambala
# Processing Record 35 of Set 9 | orlov
# Processing Record 36 of Set 9 | barcelos
# Processing Record 37 of Set 9 | santa fe
# Processing Record 38 of Set 9 | dalandzadgad
# Processing Record 39 of Set 9 | mongo
# Processing Record 40 of Set 9 | mbanza kongo
# Processing Record 41 of Set 9 | itaituba
# Processing Record 42 of Set 9 | as sulayyil
# Processing Record 43 of Set 9 | nioki
# Processing Record 44 of Set 9 | isola di capo rizzuto
# Processing Record 45 of Set 9 | la ronge
# Processing Record 46 of Set 9 | lompoc
# Processing Record 47 of Set 9 | hashtrud
# Processing Record 48 of Set 9 | borodulikha
# Processing Record 49 of Set 9 | yeppoon
# Processing Record 0 of Set 10 | i-n-salah
# Processing Record 1 of Set 10 | turbat
# Processing Record 2 of Set 10 | georgievka
# Processing Record 3 of Set 10 | midvagur
# Processing Record 4 of Set 10 | caleta de carquin
# Processing Record 5 of Set 10 | ceerigaabo
# Processing Record 6 of Set 10 | motueka
# Processing Record 7 of Set 10 | watertown
# Processing Record 8 of Set 10 | bantva
# Processing Record 9 of Set 10 | ampanihy
# Processing Record 10 of Set 10 | greater sudbury
# Processing Record 11 of Set 10 | vennesla
# Processing Record 12 of Set 10 | praia
# Processing Record 13 of Set 10 | khandyga
# Processing Record 14 of Set 10 | beaufort west
# Processing Record 15 of Set 10 | vilyuchinsk
# Processing Record 16 of Set 10 | bjelovar
# Processing Record 17 of Set 10 | revda
# Processing Record 18 of Set 10 | bukoba
# Processing Record 19 of Set 10 | linxia chengguanzhen
# Processing Record 20 of Set 10 | hirara
# Processing Record 21 of Set 10 | rasht
# Processing Record 22 of Set 10 | northam
# Processing Record 23 of Set 10 | taos
# Processing Record 24 of Set 10 | arkhangel'sk
# Processing Record 25 of Set 10 | sabang
# Processing Record 26 of Set 10 | apatity
# Processing Record 27 of Set 10 | faya-largeau
# Processing Record 28 of Set 10 | usinsk
# Processing Record 29 of Set 10 | eirunepe
# Processing Record 30 of Set 10 | san luis de la loma
# Processing Record 31 of Set 10 | urumqi
# Processing Record 32 of Set 10 | hangal
# Processing Record 33 of Set 10 | pedro ii
# Processing Record 34 of Set 10 | omdurman
# Processing Record 35 of Set 10 | acajutla
# Processing Record 36 of Set 10 | ust-tsilma
# Processing Record 37 of Set 10 | hasaki
# Processing Record 38 of Set 10 | kapa'a
# Processing Record 39 of Set 10 | richards bay
# Processing Record 40 of Set 10 | les cayes
# Processing Record 41 of Set 10 | mazagao
# Processing Record 42 of Set 10 | opuwo
# Processing Record 43 of Set 10 | upington
# Processing Record 44 of Set 10 | victoria falls
# Processing Record 45 of Set 10 | la'ie
# Processing Record 46 of Set 10 | huanren
# Processing Record 47 of Set 10 | zouerate
# Processing Record 48 of Set 10 | skagen
# Processing Record 49 of Set 10 | gantang
# Processing Record 0 of Set 11 | buurhakaba
# Processing Record 1 of Set 11 | kirensk
# Processing Record 2 of Set 11 | duncan
# Processing Record 3 of Set 11 | deqen
# Processing Record 4 of Set 11 | hyesan
# Processing Record 5 of Set 11 | mount pleasant
# Processing Record 6 of Set 11 | talodi
# Processing Record 7 of Set 11 | arroyo
# Processing Record 8 of Set 11 | nemuro
# Processing Record 9 of Set 11 | barra do garcas
# Processing Record 10 of Set 11 | rio gallegos
# Processing Record 11 of Set 11 | sibay
# Processing Record 12 of Set 11 | colihaut
# City not found. Skipping...
# Processing Record 13 of Set 11 | vila franca do campo
# Processing Record 14 of Set 11 | donetsk
# Processing Record 15 of Set 11 | shakawe
# Processing Record 16 of Set 11 | njombe
# Processing Record 17 of Set 11 | goundam
# Processing Record 18 of Set 11 | langsa
# Processing Record 19 of Set 11 | meadow lakes
# Processing Record 20 of Set 11 | tres arroyos
# Processing Record 21 of Set 11 | karyes
# Processing Record 22 of Set 11 | ebon
# Processing Record 23 of Set 11 | mitu
# Processing Record 24 of Set 11 | port saint john's
# Processing Record 25 of Set 11 | nizao
# Processing Record 26 of Set 11 | hithadhoo
# Processing Record 27 of Set 11 | gwadar
# Processing Record 28 of Set 11 | adoni
# Processing Record 29 of Set 11 | maamba
# Processing Record 30 of Set 11 | aquitania
# Processing Record 31 of Set 11 | mount isa
# Processing Record 32 of Set 11 | freeport
# Processing Record 33 of Set 11 | pokrovo-prigorodnoye
# Processing Record 34 of Set 11 | lensk
# Processing Record 35 of Set 11 | chonchi
# Processing Record 36 of Set 11 | ji'an
# Processing Record 37 of Set 11 | shenjiamen
# Processing Record 38 of Set 11 | douglas
# Processing Record 39 of Set 11 | sainte-adele
# Processing Record 40 of Set 11 | viedma
# Processing Record 41 of Set 11 | illizi
# Processing Record 42 of Set 11 | raufoss
# Processing Record 43 of Set 11 | fort st. john
# Processing Record 44 of Set 11 | yeosu
# Processing Record 45 of Set 11 | broken hill
# Processing Record 46 of Set 11 | holualoa
# Processing Record 47 of Set 11 | awjilah
# Processing Record 48 of Set 11 | fort wellington
# Processing Record 49 of Set 11 | traverse city
# Processing Record 0 of Set 12 | saint-pol-sur-mer
# Processing Record 1 of Set 12 | krasnovishersk
# Processing Record 2 of Set 12 | ribas do rio pardo
# Processing Record 3 of Set 12 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 4 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 5 of Set 12 | sogndal
# Processing Record 6 of Set 12 | al-`ula
# City not found. Skipping...
# Processing Record 7 of Set 12 | camapua
# Processing Record 8 of Set 12 | mata-utu
# Processing Record 9 of Set 12 | kultali
# City not found. Skipping...
# Processing Record 10 of Set 12 | al qusiyah
# Processing Record 11 of Set 12 | adam
# Processing Record 12 of Set 12 | nkurenkuru
# City not found. Skipping...
# Processing Record 13 of Set 12 | mont-roig del camp
# Processing Record 14 of Set 12 | mugia
# Processing Record 15 of Set 12 | jatibarang
# Processing Record 16 of Set 12 | urangan
# Processing Record 17 of Set 12 | pimentel
# Processing Record 18 of Set 12 | beau vallon
# Processing Record 19 of Set 12 | gavrilov posad
# Processing Record 20 of Set 12 | sikasso
# Processing Record 21 of Set 12 | general cabrera
# Processing Record 22 of Set 12 | ghat
# Processing Record 23 of Set 12 | puerto penasco
# Processing Record 24 of Set 12 | benghazi
# Processing Record 25 of Set 12 | muar
# Processing Record 26 of Set 12 | peterhead
# Processing Record 27 of Set 12 | mossendjo
# Processing Record 28 of Set 12 | campo gallo
# Processing Record 29 of Set 12 | kuressaare
# Processing Record 30 of Set 12 | coahuayana de hidalgo
# Processing Record 31 of Set 12 | bodaybo
# Processing Record 32 of Set 12 | mutsu
# Processing Record 33 of Set 12 | sorong
# Processing Record 34 of Set 12 | howrah
# Processing Record 35 of Set 12 | pagsangahan
# Processing Record 36 of Set 12 | coxen hole
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Display sample data
city_data_df
# Out:
#                        Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City
# grytviken         -54.2811  -36.5092     -6.11        77          26
# afaahiti          -17.7500 -149.2833     27.93        77          59
# port-aux-francais -49.3500   70.2167      5.68        90          80
# uturoa            -16.7333 -151.4333     25.79        76          47
# georgetown          5.4112  100.3354     27.96        83          20
# ...                    ...       ...       ...       ...         ...
# mutsu              41.2894  141.2169     25.48        75          97
# sorong             -0.8833  131.2500     24.97        89          95
# howrah             22.5892   88.3103     27.00       100          40
# pagsangahan        13.2158  122.5431     27.91        78         100
# coxen hole         16.3244  -86.5366     30.60        62           0
#
#                    Wind Speed Country        Date
# City
# grytviken                3.79      GS  1690153851
# afaahiti                 4.98      PF  1690153852
# port-aux-francais       15.36      TF  1690153852
# uturoa                   5.42      PF  1690153574
# georgetown               1.03      MY  1690153815
# ...                       ...     ...         ...
# mutsu                    1.60      JP  1690153911
# sorong                   6.06      ID  1690153911
# howrah                   0.00      IN  1690153626
# pagsangahan              6.22      PH  1690153911
# coxen hole              10.29      HN  1690153911
#
# [566 rows x 8 columns]

# %%
import os

# Create the 'output_data' directory if it doesn't exist
if not os.path.exists('output_data'):
    os.makedirs('output_data')

# Save the DataFrame to a CSV file in the 'output_data' directory
output_file = 'output_data/city_weather_data.csv'
city_data_df.to_csv(output_file, index=False)

# %%
# Read saved data
city_data_df = pd.read_csv('output_data/city_weather_data.csv', index_col="City")

# Display sample data
city_data_df
# Out:
#                        Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City
# grytviken         -54.2811  -36.5092     -6.11        77          26
# afaahiti          -17.7500 -149.2833     27.93        77          59
# port-aux-francais -49.3500   70.2167      5.68        90          80
# uturoa            -16.7333 -151.4333     25.79        76          47
# georgetown          5.4112  100.3354     27.96        83          20
# ...                    ...       ...       ...       ...         ...
# mutsu              41.2894  141.2169     25.48        75          97
# sorong             -0.8833  131.2500     24.97        89          95
# howrah             22.5892   88.3103     27.00       100          40
# pagsangahan        13.2158  122.5431     27.91        78         100
# coxen hole         16.3244  -86.5366     30.60        62           0
#
#                    Wind Speed Country        Date
# City
# grytviken                3.79      GS  1690153851
# afaahiti                 4.98      PF  1690153852
# port-aux-francais       15.36      TF  1690153852
# uturoa                   5.42      PF  1690153574
# georgetown               1.03      MY  1690153815
# ...                       ...     ...         ...
# mutsu                    1.60      JP  1690153911
# sorong                   6.06      ID  1690153911
# howrah                   0.00      IN  1690153626
# pagsangahan              6.22      PH  1690153911
# coxen hole              10.29      HN  1690153911
#
# [566 rows x 8 columns]

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature (Date)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity (Date)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness (Date)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker='o', edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed (Date)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
def create_scatter_plot_with_regression(x, y, x_label, y_label, title, save_file_name=None):
    """
    Create a scatter plot with linear regression.

    Parameters:
        x (list or array): The x-axis data.
        y (list or array): The y-axis data.
        x_label (str): Label for the x-axis.
        y_label (str): Label for the y-axis.
        title (str): Title of the plot.
        save_file_name (str, optional): If provided, the plot will be saved with this filename.

    Returns:
        None
    """
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    regression_line = [slope * xi + intercept for xi in x]

    # Create scatter plot
    plt.scatter(x, y, marker='o', edgecolors='black')

    # Plot the regression line
    plt.plot(x, regression_line, color='red', label='Regression Line')

    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

    # Add the model's formula and R-squared value to the plot
    plt.text(min(x), max(y), f"y = {slope:.2f}x + {intercept:.2f}", fontsize=12, color='blue')
    plt.text(min(x), max(y) - (max(y) - min(y)) * 0.1, f"R² = {r_value**2:.2f}", fontsize=12, color='blue')

    # Add legend
    plt.legend()

    # Show the plot or save it if a filename is provided
    if save_file_name:
        plt.savefig(save_file_name)
    else:
        plt.show()

# %%
# Create a DataFrame with Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df
# Out:
#                      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City
# georgetown        5.4112  100.3354     27.96        83          20
# remire-montjoly   4.9167  -52.2667     26.02        89           0
# cudahy           33.9606 -118.1853     37.73        68           0
# kodiak           57.7900 -152.4072     17.73        68           0
# porto novo        6.4965    2.6036     23.57        94         100
# ...                  ...       ...       ...       ...         ...
# bodaybo          57.8506  114.1933     21.52        67           7
# mutsu            41.2894  141.2169     25.48        75          97
# howrah           22.5892   88.3103     27.00       100          40
# pagsangahan      13.2158  122.5431     27.91        78         100
# coxen hole       16.3244  -86.5366     30.60        62           0
#
#                  Wind Speed Country        Date
# City
# georgetown             1.03      MY  1690153815
# remire-montjoly        1.54      GF  1690153854
# cudahy                 4.12      US  1690153854
# kodiak                 4.12      US  1690153668
# porto novo             3.03      BJ  1690153854
# ...                     ...     ...         ...
# bodaybo                0.50      RU  1690153911
# mutsu                  1.60      JP  1690153911
# howrah                 0.00      IN  1690153626
# pagsangahan            6.22      PH  1690153911
# coxen hole            10.29      HN  1690153911
#
# [402 rows x 8 columns]

# %%
# Create a DataFrame with Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df
# Out:
#                        Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City
# grytviken         -54.2811  -36.5092     -6.11        77          26
# afaahiti          -17.7500 -149.2833     27.93        77          59
# port-aux-francais -49.3500   70.2167      5.68        90          80
# uturoa            -16.7333 -151.4333     25.79        76          47
# bredasdorp        -34.5322   20.0403      9.56        74          55
# ...                    ...       ...       ...       ...         ...
# beau vallon       -20.4189   57.6953     22.13        88          75
# general cabrera   -32.8131  -63.8724     11.12        39         100
# mossendjo          -2.9506   12.7261     20.85        82          97
# campo gallo       -26.5833  -62.8500     17.60        46           3
# sorong             -0.8833  131.2500     24.97        89          95
#
#                    Wind Speed Country        Date
# City
# grytviken                3.79      GS  1690153851
# afaahiti                 4.98      PF  1690153852
# port-aux-francais       15.36      TF  1690153852
# uturoa                   5.42      PF  1690153574
# bredasdorp               2.75      ZA  1690153425
# ...                       ...     ...         ...
# beau vallon              5.14      MU  1690153910
# general cabrera          2.63      AR  1690153910
# mossendjo                1.90      CG  1690153911
# campo gallo              3.34      AR  1690153911
# sorong                   6.06      ID  1690153911
#
# [164 rows x 8 columns]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere: Temperature vs. Latitude
create_scatter_plot_with_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],
                                    'Latitude', 'Temperature (°C)', 'Northern Hemisphere: Temperature vs. Latitude',
                                    'output_data/northern_temperature_regression_plot.png')

# %%
# Southern Hemisphere: Temperature vs. Latitude
create_scatter_plot_with_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],
                                    'Latitude', 'Temperature (°C)', 'Southern Hemisphere: Temperature vs. Latitude',
                                    'output_data/southern_temperature_regression_plot.png')

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere: Humidity vs. Latitude
create_scatter_plot_with_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'],
                                    'Latitude', 'Humidity (%)', 'Northern Hemisphere: Humidity vs. Latitude',
                                    'output_data/northern_humidity_regression_plot.png')

# %%
# Southern Hemisphere: Humidity vs. Latitude
create_scatter_plot_with_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'],
                                    'Latitude', 'Humidity (%)', 'Southern Hemisphere: Humidity vs. Latitude',
                                    'output_data/southern_humidity_regression_plot.png')

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere: Cloudiness vs. Latitude
create_scatter_plot_with_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'],
                                    'Latitude', 'Cloudiness (%)', 'Northern Hemisphere: Cloudiness vs. Latitude',
                                    'output_data/northern_cloudiness_regression_plot.png')

# %%
# Southern Hemisphere: Cloudiness vs. Latitude
create_scatter_plot_with_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'],
                                    'Latitude', 'Cloudiness (%)', 'Southern Hemisphere: Cloudiness vs. Latitude',
                                    'output_data/southern_cloudiness_regression_plot.png')

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere: Wind Speed vs. Latitude
create_scatter_plot_with_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'],
                                    'Latitude', 'Wind Speed (m/s)', 'Northern Hemisphere: Wind Speed vs. Latitude',
                                    'output_data/northern_wind_speed_regression_plot.png')

# %%
# Southern Hemisphere: Wind Speed vs. Latitude
create_scatter_plot_with_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'],
                                    'Latitude', 'Wind Speed (m/s)', 'Southern Hemisphere: Wind Speed vs. Latitude',
                                    'output_data/southern_wind_speed_regression_plot.png')
