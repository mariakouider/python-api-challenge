# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/city_weather_data.csv")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          grytviken -54.2811  -36.5092     -6.11        77          26
# 1           afaahiti -17.7500 -149.2833     27.93        77          59
# 2  port-aux-francais -49.3500   70.2167      5.68        90          80
# 3             uturoa -16.7333 -151.4333     25.79        76          47
# 4         georgetown   5.4112  100.3354     27.96        83          20
#
#    Wind Speed Country        Date
# 0        3.79      GS  1690153851
# 1        4.98      PF  1690153852
# 2       15.36      TF  1690153852
# 3        5.42      PF  1690153574
# 4        1.03      MY  1690153815

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(x='Lng', y='Lat', size='Humidity', title='City Humidity Map', hover_cols=['City', 'Country'],color="City",tiles="OSM",geo=True)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
ideal_weather_df = city_data_df[(city_data_df['Max Temp'] > 20) & (city_data_df['Max Temp'] < 30) & (city_data_df['Wind Speed'] < 10) & (city_data_df['Cloudiness'] < 50)].dropna()

# Drop any rows with null values
ideal_weather_df.dropna(inplace=True)

# Display sample data
ideal_weather_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3             uturoa -16.7333 -151.4333     25.79        76          47
# 4         georgetown   5.4112  100.3354     27.96        83          20
# 9    remire-montjoly   4.9167  -52.2667     26.02        89           0
# 13         adamstown -25.0660 -130.1015     20.43        69          22
# 19            mizdah  31.4451   12.9801     28.68        22           0
# ..               ...      ...       ...       ...       ...         ...
# 544       jatibarang  -6.4747  108.3153     22.99        76          46
# 546         pimentel  -6.8367  -79.9342     24.16        73          20
# 553         benghazi  32.1167   20.0667     28.82        70           0
# 560          bodaybo  57.8506  114.1933     21.52        67           7
# 563           howrah  22.5892   88.3103     27.00       100          40
#
#      Wind Speed Country        Date
# 3          5.42      PF  1690153574
# 4          1.03      MY  1690153815
# 9          1.54      GF  1690153854
# 13         7.65      PN  1690153854
# 19         3.27      LY  1690153855
# ..          ...     ...         ...
# 544        2.28      ID  1690153909
# 546        9.26      PE  1690153910
# 553        5.02      LY  1690153910
# 560        0.50      RU  1690153911
# 563        0.00      IN  1690153626
#
# [138 rows x 9 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 3             uturoa      PF -16.7333 -151.4333        76
# 4         georgetown      MY   5.4112  100.3354        83
# 9    remire-montjoly      GF   4.9167  -52.2667        89
# 13         adamstown      PN -25.0660 -130.1015        69
# 19            mizdah      LY  31.4451   12.9801        22
# ..               ...     ...      ...       ...       ...        ...
# 544       jatibarang      ID  -6.4747  108.3153        76
# 546         pimentel      PE  -6.8367  -79.9342        73
# 553         benghazi      LY  32.1167   20.0667        70
# 560          bodaybo      RU  57.8506  114.1933        67
# 563           howrah      IN  22.5892   88.3103       100
#
# [138 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000  # assuming you want to search within a 10,000 meters radius
params = {
    'apiKey': geoapify_key,
    'categories': "accommodation.hotel",
    'limit': 20,
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lon = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lon},{lat},{radius}'
    params["bias"] = f'proximity:{lon},{lat}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
    
    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df

# Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# Configure the map plot
map_plot_with_hotels = hotel_df.hvplot.points(x='Longitude', y='Latitude', size='Humidity', title='City Humidity Map with Hotels', hover_cols=['City', 'Country', 'Hotel Name'], geo=True)

# Display the map with hotels
map_plot_with_hotels
# Out:
# Starting hotel search
# uturoa - nearest hotel: Hawaiki Nui hotel
# georgetown - nearest hotel: Page 63 hostel
# remire-montjoly - nearest hotel: Complexe Belova
# adamstown - nearest hotel: No hotel found
# mizdah - nearest hotel: No hotel found
# tazacorte - nearest hotel: App Leyma
# reyes - nearest hotel: Hotel Santa Rosa
# arraial do cabo - nearest hotel: No hotel found
# bayganin - nearest hotel: No hotel found
# san ignacio de velasco - nearest hotel: Hotel Caparu
# luanda - nearest hotel: Hotel Forum
# val-d'or - nearest hotel: Quality Inn & Suites
# saguenay - nearest hotel: Le Montagnais
# guerrero negro - nearest hotel: Plaza sal paraiso
# kassala - nearest hotel: No hotel found
# roma - nearest hotel: Wingate by Wyndham Rome
# fale old settlement - nearest hotel: No hotel found
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# negombo - nearest hotel: Choys Waterfront Residence
# aketi - nearest hotel: Hôtel Mabinza
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# ribeira grande - nearest hotel: Hospedaria JSF
# vila velha - nearest hotel: Hotel Prainha
# cabedelo - nearest hotel: No hotel found
# mejit - nearest hotel: No hotel found
# jamestown - nearest hotel: DoubleTree Jamestown
# cockburn town - nearest hotel: The Salt Raker Inn
# pont rouge - nearest hotel: No hotel found
# okhotsk - nearest hotel: No hotel found
# touros - nearest hotel: Pousada Atlântico
# taraz - nearest hotel: Анель
# krasnogvardeyskoye - nearest hotel: No hotel found
# katsuura - nearest hotel: 潮騒の宿
# okha - nearest hotel: Сфера
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# callao - nearest hotel: Casa Ronald
# pathein - nearest hotel: Taan Taan Ta
# malanje - nearest hotel: Hotel PORTVGALIA
# hamilton - nearest hotel: North Vista Manor
# atafu village - nearest hotel: No hotel found
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# robore - nearest hotel: Lajas
# flin flon - nearest hotel: Copperbelt Hotel
# kuching - nearest hotel: Hotel Samudera
# nyurba - nearest hotel: Марина
# razdol'noye - nearest hotel: Портовое
# andkhoy - nearest hotel: No hotel found
# mahibadhoo - nearest hotel: No hotel found
# torrington - nearest hotel: Yankee Pedlar Inn
# shingu - nearest hotel: ホテルニューパレス
# conceicao da barra - nearest hotel: Porto Marlin Hotel
# horta - nearest hotel: Azoris Faial Garden - Resort Hotel
# kapsan-up - nearest hotel: No hotel found
# dryden - nearest hotel: Holiday Inn Express
# manado - nearest hotel: Swiss Belhotel
# limon - nearest hotel: Hotel NG
# barre - nearest hotel: Quality Inn Barre-Montpelier
# port mathurin - nearest hotel: Escale Vacances
# kone - nearest hotel: Pacifik Appartels
# sparti - nearest hotel: Maniatis
# thompson - nearest hotel: Thompson Inn
# santo antonio - nearest hotel: Pousada Onça Puma
# kailua-kona - nearest hotel: Kona Seaside Hotel
# verkhnevilyuysk - nearest hotel: No hotel found
# itamaraca - nearest hotel: No hotel found
# ajaccio - nearest hotel: Hôtel Sole e Monte
# paracuru - nearest hotel: Vento Brasil
# juan de ayolas - nearest hotel: Hotel Nacional de Turismo Ayolas
# pinarhisar - nearest hotel: Hotel Önder
# dawson creek - nearest hotel: Comfort Inn
# huarmey - nearest hotel: Hostal Santa Rosa
# chelak - nearest hotel: No hotel found
# qingdao - nearest hotel: Le Méridien Qingdao
# saint-philippe - nearest hotel: Le Baril
# ribeira brava - nearest hotel: Cheerfulway Bravamar Hotel
# parambu - nearest hotel: No hotel found
# berdigestyakh - nearest hotel: No hotel found
# ta`u - nearest hotel: No hotel found
# inongo - nearest hotel: Chez LELE IYOLO
# ilebo - nearest hotel: Hôtel des Palmes
# nishinoomote - nearest hotel: ゼウスハウス
# soio - nearest hotel: Hotel Maria Teres
# manggar - nearest hotel: No hotel found
# badger - nearest hotel: Hotel North Pole
# machico - nearest hotel: Residence Inn
# fomboni - nearest hotel: Mohéli La Plage
# west island - nearest hotel: Cocos Village Bungalows
# eastham - nearest hotel: Four Points by Sheraton
# ingeniero guillermo n. juarez - nearest hotel: Hotel El Indiano
# yorkton - nearest hotel: Ramada Yorkton
# ilheus - nearest hotel: No hotel found
# praia da vitoria - nearest hotel: Salles
# rongelap - nearest hotel: No hotel found
# posto fiscal rolim de moura - nearest hotel: No hotel found
# chibougamau - nearest hotel: No hotel found
# florida - nearest hotel: Chassahowitzka Hotel
# yarmouth - nearest hotel: The Inn At Cape Cod
# wanning - nearest hotel: No hotel found
# broome - nearest hotel: No hotel found
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# businga - nearest hotel: Hôtel Roho
# dakhla - nearest hotel: Hotel El Massira
# kralendijk - nearest hotel: Hotel Bonaire Inn
# dalandzadgad - nearest hotel: Хан Уул буудал
# mongo - nearest hotel: No hotel found
# mbanza kongo - nearest hotel: Hotel Estrela de Congo
# nioki - nearest hotel: No hotel found
# hashtrud - nearest hotel: No hotel found
# caleta de carquin - nearest hotel: Hotel Mi Choacan
# watertown - nearest hotel: Four Points by Sheraton Boston Newton
# praia - nearest hotel: Casa Sodadi
# khandyga - nearest hotel: Апельсин
# hirara - nearest hotel: 古謝そば屋
# rasht - nearest hotel: Hotel Ordibehesht
# eirunepe - nearest hotel: No hotel found
# urumqi - nearest hotel: 百时快捷酒店红山店
# hyesan - nearest hotel: No hotel found
# arroyo - nearest hotel: El Jardín de la Abadía
# barra do garcas - nearest hotel: Pousada Portal
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# meadow lakes - nearest hotel: No hotel found
# karyes - nearest hotel: Hotel Parnon
# ebon - nearest hotel: No hotel found
# freeport - nearest hotel: The Freeport Inn and Marina
# lensk - nearest hotel: No hotel found
# ji'an - nearest hotel: 华侨国际酒店
# sainte-adele - nearest hotel: B&B Pantoufles et Pamplemousse
# holualoa - nearest hotel: Kona Hotel
# fort wellington - nearest hotel: No hotel found
# traverse city - nearest hotel: The Whiting
# ribas do rio pardo - nearest hotel: Hotel São Francisco
# camapua - nearest hotel: No hotel found
# mata-utu - nearest hotel: Gîte Oceania
# jatibarang - nearest hotel: Sejahtera Abadi
# pimentel - nearest hotel: Hospedaje Calle del Sol
# benghazi - nearest hotel: ترجاب
# bodaybo - nearest hotel: НОЙ
# howrah - nearest hotel: Sun India Guest House
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# Cell In[16], line 47
#      42 hotel_df
#      44 # Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.
#      45
#      46 # Configure the map plot
# ---> 47 map_plot_with_hotels = hotel_df.hvplot.points(x='Longitude', y='Latitude', size='Humidity', title='City Humidity Map with Hotels', hover_cols=['City', 'Country', 'Hotel Name'], geo=True)
#      49 # Display the map with hotels
#      50 map_plot_with_hotels
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/hvplot/plotting/core.py:1626, in hvPlotTabular.points(self, x, y, **kwds)
#    1568 def points(self, x=None, y=None, **kwds):
#    1569     """
#    1570     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1571     geographic plots.
#    (...)
#    1624     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1625     """
# -> 1626     return self(x, y, kind="points", **kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/hvplot/plotting/core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/hvplot/converter.py:1249, in HoloViewsConverter.__call__(self, kind, x, y)
#    1247                 dataset = Dataset(data)
#    1248             dataset = dataset.redim(**self._redim)
# -> 1249         obj = method(x, y)
#    1250         obj._dataset = dataset
#    1252 if self.crs and self.project:
#    1253     # Apply projection before rasterizing
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/hvplot/converter.py:2277, in HoloViewsConverter.points(self, x, y, data)
#    2275 def points(self, x=None, y=None, data=None):
#    2276     self._error_if_unavailable('points')
# -> 2277     return self._geom_plot(x, y, data, kind='points')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/hvplot/converter.py:2261, in HoloViewsConverter._geom_plot(self, x, y, data, kind)
#    2259         obj = obj.overlay(sort=False)
#    2260 else:
# -> 2261     obj = element(data, kdims, vdims, **params)
#    2263 return (obj.redim(**redim)
#    2264         .opts({element.name: cur_opts}, backend='bokeh')
#    2265         .opts({element.name: compat_opts}, backend=self._backend_compat))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geoviews/element/geo.py:113, in _Element.__init__(self, data, kdims, vdims, **kwargs)
#     111 elif isinstance(data, _Element):
#     112     kwargs['crs'] = data.crs
# --> 113 super().__init__(data, kdims=kdims, vdims=vdims, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/holoviews/element/selection.py:24, in SelectionIndexExpr.__init__(self, *args, **kwargs)
#      23 def __init__(self, *args, **kwargs):
# ---> 24     super().__init__(*args, **kwargs)
#      25     self._index_skip = False
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/holoviews/core/data/__init__.py:335, in Dataset.__init__(self, data, kdims, vdims, **kwargs)
#     333 (data, self.interface, dims, extra_kws) = initialized
#     334 super().__init__(data, **dict(kwargs, **dict(dims, **extra_kws)))
# --> 335 self.interface.validate(self, validate_vdims)
#     337 # Handle _pipeline property
#     338 if input_pipeline is None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/holoviews/core/data/pandas.py:168, in PandasInterface.validate(cls, dataset, vdims)
#     166 not_found = [d for d in dimensions if d not in cols]
#     167 if not_found:
# --> 168     raise DataError("Supplied data does not contain specified "
#     169                     "dimensions, the following dimensions were "
#     170                     "not found: %s" % repr(not_found), cls)
#
# DataError: Supplied data does not contain specified dimensions, the following dimensions were not found: ['Longitude', 'Latitude']
#
# PandasInterface expects tabular data, for more information on supported datatypes see http://holoviews.org/user_guide/Tabular_Datasets.html

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_with_hotels = hotel_df.hvplot.points(x='Longitude', y='Latitude', size='Humidity', title='City Humidity Map with Hotels', hover_cols=['City', 'Country', 'Hotel Name'], color="City",tiles="OSM",geo=True)

# Display the map with hotels
map_plot_with_hotels
